# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/HKF/python classes/Dataset/DataSet/BigBasket Products.csv")

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Business Case Study
# BIG BASKET ADVERRTISEMENT : GROCeries.

# What product or category has the most stock available.

# Totol Stock.

df.sale_price.sum()
# Out:
# 9219228.53

# %%
# How to check stock share of each category.

df.groupby('category')['sale_price'].sum().sort_values(ascending=False)
# Out:
# category
# Beauty & Hygiene            3404749.24
# Kitchen, Garden & Pets      1927634.12
# Gourmet & World Food        1522115.31
# Cleaning & Household         693761.09
# Foodgrains, Oil & Masala     516870.23
# Snacks & Branded Foods       364610.08
# Baby Care                    326317.17
# Beverages                    212186.67
# Bakery, Cakes & Dairy        121525.14
# Eggs, Meat & Fish            101114.12
# Fruits & Vegetables           28345.36
# Name: sale_price, dtype: float64

# %%
# As the Advertisements show Big Basket Deals in Groceries. 
# But Fruits & Vegetables takes least share in it.

# %%
df.groupby('category')['sale_price'].sum().sort_values(ascending=False)
# Out:
# category
# Beauty & Hygiene            3404749.24
# Kitchen, Garden & Pets      1927634.12
# Gourmet & World Food        1522115.31
# Cleaning & Household         693761.09
# Foodgrains, Oil & Masala     516870.23
# Snacks & Branded Foods       364610.08
# Baby Care                    326317.17
# Beverages                    212186.67
# Bakery, Cakes & Dairy        121525.14
# Eggs, Meat & Fish            101114.12
# Fruits & Vegetables           28345.36
# Name: sale_price, dtype: float64

# %%
# Data Respresentation in a Form of bar PLot

df.groupby('category')['sale_price'].sum().sort_values(ascending=False).plot(kind='bar',color='y')
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# - Beauty & Hygiene has a largest share in current stock 3404749.24

# %%
# Which sub_category has the largest market share under Beauty and Hygiene.

# %%
df.groupby(df.category=='Beauty & Hygiene')['sale_price'].sum()
# Out:
# category
# False    5814479.29
# True     3404749.24
# Name: sale_price, dtype: float64

# %%
# We can segregate Beauty and Hygiene in a new variable

bh = df[df.category=='Beauty & Hygiene']

# %%
bh.groupby('sub_category')['sale_price'].sum().sort_values(ascending=False)
# Out:
# sub_category
# Skin Care              946402.38
# Fragrances & Deos      893099.59
# Health & Medicine      414334.12
# Hair Care              394285.75
# Men's Grooming         369908.26
# Bath & Hand Wash       228908.00
# Feminine Hygiene        90271.20
# Oral Care               49391.60
# Makeup                  15812.34
# Mothers & Maternity      2336.00
# Name: sale_price, dtype: float64

# %% [markdown]
# - Skin Care is the highest Stock in Beauty and Hygiene 946402.38
# - Even it is greater than Cleaning and Household stock that is 693761.09

# %%
# Plotting the above heirarcy.

bh.groupby('sub_category')['sale_price'].sum().sort_values(ascending=False).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='sale_price'>

# %%
# Total (OVERALL DISCOUNT) given by Big Basket on all products.

df.sale_price.sum()
# Out:
# 9219228.53

# %%
df.market_price.sum()
# Out:
# 10527571.39

# %%
df.market_price.sum() - df.sale_price.sum()
# Out:
# 1308342.8600000013

# %%
# Counting discount on each item.

df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# We want ta new column of discount right after market_price that will show us the discounted amount.

df.insert(6,'discount',df.market_price-df.sale_price)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# MAtching total discount with above created column.

df.discount.sum()
# Out:
# 1307730.86

# %%
# As above mentione discount overall is 1308342
# And Iterated new column named as discount sum is 1307730.86

1308342 - 1307730

# 612₹ difference between them.
# Out:
# 612

# %%
# Maybe there are some products that will be sold more than market price.

df[df.market_price<df.sale_price]
# Out:
#                                                 product  \
# 248   4mm Aluminium Induction Base Chapati Roti Tawa...
# 288           Arrabbiata Tomato Pasta Sauce With Chilli
# 412   Original Care Lip Balm For 24h Moisture With S...
# 436                        Balloon - Polka Dot, 12 Inch
# 1249                                          Beard Kit
#
#                     category            sub_category       brand  sale_price  \
# 248   Kitchen, Garden & Pets    Cookware & Non Stick       HAZEL    111649.0
# 288     Gourmet & World Food  Sauces, Spreads & Dips   Montanini     22325.0
# 412         Beauty & Hygiene               Skin Care       Nivea      1114.8
# 436     Cleaning & Household   Party & Festive Needs    B Vishal     88899.0
# 1249        Beauty & Hygiene          Men's Grooming  Uncle Tony    112475.0
#
#       market_price  discount                      type  rating  \
# 248         1289.0 -110360.0          Tawa & Sauce Pan     NaN
# ...

# %% [markdown]
# - With this we are to find out the dirty data.

# %%
# Data Entry is not correct in Sale Price Column it differs to much with Market Price.

# We try to fill those dirty data with Orignal Market Prie itself.

# %%
df.sale_price = np.where(df.market_price<df.sale_price,df.market_price,df.sale_price)

# %%
df[248:249]
# Out:
#                                                product  \
# 248  4mm Aluminium Induction Base Chapati Roti Tawa...
#
#                    category          sub_category  brand  sale_price  \
# 248  Kitchen, Garden & Pets  Cookware & Non Stick  HAZEL      1289.0
#
#      market_price  discount              type  rating  \
# 248        1289.0 -110360.0  Tawa & Sauce Pan     NaN
#
#                                            description
# 248  Hazel Aluminium Tawa has an ergonomic design f...

# %%
df.insert(6,'discount_new',df.market_price-df.sale_price)

# %%
df[248:249]
# Out:
#                                                product  \
# 248  4mm Aluminium Induction Base Chapati Roti Tawa...
#
#                    category          sub_category  brand  sale_price  \
# 248  Kitchen, Garden & Pets  Cookware & Non Stick  HAZEL      1289.0
#
#      market_price  discount_new  discount              type  rating  \
# 248        1289.0           0.0 -110360.0  Tawa & Sauce Pan     NaN
#
#                                            description
# 248  Hazel Aluminium Tawa has an ergonomic design f...

# %%
df.drop('discount',axis=1,inplace=True)

# %%
df[248:249]
# Out:
#                                                product  \
# 248  4mm Aluminium Induction Base Chapati Roti Tawa...
#
#                    category          sub_category  brand  sale_price  \
# 248  Kitchen, Garden & Pets  Cookware & Non Stick  HAZEL      1289.0
#
#      market_price  discount_new              type  rating  \
# 248        1289.0           0.0  Tawa & Sauce Pan     NaN
#
#                                            description
# 248  Hazel Aluminium Tawa has an ergonomic design f...

# %%
# Let's Check for the Difference Now:

df.discount_new.sum()
# Out:
# 1639010.66

# %%
df.market_price.sum() - df.sale_price.sum()
# Out:
# 1639622.6600000001

# %%
# Still it has a Difference of 612 ₹.
# There is a reson maybe one of them contains null values

# %%
# Check for the Null Values

df.isnull().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# discount_new       6
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
df[df.sale_price.isnull()]
# Out:
#                                                 product  \
# 1719            Puja Flower Wicks - Puvvu Vathulu Batti
# 1720                                    Powder - Sambar
# 1721  Steel Fork - Medium, Premium Excel Series, BBCL08
# 1722                                 Snack Mix - Dhokla
# 2401                              Battery AA 3UT Hi Top
# 2402        Klassic Plain Cocktail Napkins (22 X 22 cm)
#
#                       category              sub_category       brand  \
# 1719      Cleaning & Household               Pooja Needs        Jaji
# 1720  Foodgrains, Oil & Masala          Masalas & Spices  Annapoorna
# 1721    Kitchen, Garden & Pets        Crockery & Cutlery     BB Home
# 1722    Snacks & Branded Foods       Ready To Cook & Eat         MTR
# 2401    Kitchen, Garden & Pets  Appliances & Electricals       Nippo
# 2402      Cleaning & Household  Disposables, Garbage Bag     Origami
#
#       sale_price  market_price  discount_new                     type  rating  \
# ...

# %%
# 612 ₹ was uneven due to null values.

# Fill the Null values in Sale Price.
# Best Option is to fill them with Market Price itself.

df.sale_price = df.sale_price.fillna(df.market_price)

# %%
df.isnull().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# discount_new       6
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
# Check the Difference Now !!!

df.discount_new.sum()
# Out:
# 1639010.66

# %%
df.market_price.sum() - df.sale_price.sum()
# Out:
# 1639010.6600000001

# %%
# Both Data Match accordingly

# %%
# Brand that repet itself the most ?

df.brand.value_counts()
# Out:
# brand
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
#                    ...
# Wellastrate           1
# Clean & Fresh         1
# Lal                   1
# Glint                 1
# Baron De Bercy        1
# Name: count, Length: 2313, dtype: int64

# %% [markdown]
# - Big Basket has its own brands two of them in top 5  (bb royal & bb Home)
# - FRESHO is the brand with most products

# %%
# Which Category has the most ratings and least ratings

df.isnull().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# discount_new       6
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
# Rating contains highest Null Values.

df.rating = df.rating.fillna(df.rating.median())

# %%
df.groupby('category')['rating'].mean().sort_values(ascending=False)
# Out:
# category
# Eggs, Meat & Fish           4.100000
# Fruits & Vegetables         4.100000
# Beverages                   4.089153
# Foodgrains, Oil & Masala    4.069021
# Gourmet & World Food        4.040853
# Baby Care                   4.038033
# Snacks & Branded Foods      3.997477
# Cleaning & Household        3.987439
# Beauty & Hygiene            3.982306
# Bakery, Cakes & Dairy       3.952409
# Kitchen, Garden & Pets      3.844162
# Name: rating, dtype: float64

# %% [markdown]
# - Eggs, Meat & Fish and Fruits & Vegetables has the highest Ratings.
# - Why those 2 have the highest ratings (Limited data).
# - These 2 are very less in compared to other categories
# - Eggs, Meat & Fish thsi one has only 350 Products.
# - Fruits & Vegetables has 557 Products in dataset.
# - In total data that is 27555 its not even 5%.

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Which sub_category give the most and least discount

df.groupby('category')['discount_new'].sum().sort_values(ascending=False)
# Out:
# category
# Beauty & Hygiene            588042.78
# Kitchen, Garden & Pets      543851.28
# Gourmet & World Food        180878.64
# Foodgrains, Oil & Masala     98916.77
# Cleaning & Household         96107.26
# Baby Care                    37702.83
# Snacks & Branded Foods       31466.42
# Beverages                    28740.33
# Eggs, Meat & Fish            12928.30
# Bakery, Cakes & Dairy        12831.86
# Fruits & Vegetables           7544.19
# Name: discount_new, dtype: float64

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Which Sub category has the most repeted brand

df.groupby('category')['brand'].value_counts().sort_values(ascending=False)
# Out:
# category                  brand
# Fruits & Vegetables       Fresho           544
# Foodgrains, Oil & Masala  bb Royal         525
# Kitchen, Garden & Pets    BB Home          299
# Beauty & Hygiene          INATUR           146
# Kitchen, Garden & Pets    DP               136
#                                           ...
# Foodgrains, Oil & Masala  LG                 1
#                           LAXMI NARAYAN      1
#                           Kpl Shudhi         1
#                           Kpl                1
# Snacks & Branded Foods    Jiva Ayurveda      1
# Name: count, Length: 2780, dtype: int64

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
# Which is the Highest and Lowest Product w.r.t Price

df.sale_price.max()
# Out:
# 12500.0

# %%
# Check for the product (Highest)

df[df.sale_price==df.sale_price.max()]
# Out:
#                product                category            sub_category brand  \
# 25301  Bravura Clipper  Kitchen, Garden & Pets  Pet Food & Accessories  Wahl
#
#        sale_price  market_price  discount_new                     type  \
# 25301     12500.0       12500.0           0.0  Pet Cleaning & Grooming
#
#        rating                                        description
# 25301     4.1  The bravura clipper is a must-have clipper for...

# %%
# Check for the product (Lowest)

df[df.sale_price==df.sale_price.min()]
# Out:
#             product             category        sub_category   brand  \
# 26976  Curry Leaves  Fruits & Vegetables  Herbs & Seasonings  Fresho
#
#        sale_price  market_price  discount_new                   type  rating  \
# 26976        2.45          15.0         12.55  Indian & Exotic Herbs     4.1
#
#                                              description
# 26976  With dark green and glossy appearance, curry l...

# %%
# Top 10 most expensive Products in this Data.

df.sort_values(by='sale_price',ascending=False)
# Out:
#                                                  product  \
# 25301                                    Bravura Clipper
# 21761      Pet Food - N&D Team Breeder Puppy Top Farmina
# 12669                   Epilator SE9-9961 Legs-Body-Face
# 23082  Gas Stove-4 Burner Royale Plus Schott Glass, B...
# 2781                              Extra Virgin Olive Oil
# ...                                                  ...
# 27413                                Layer Cake - Orange
# 17943                              Fulltoss Tangy Tomato
# 2978                Sugar Free Chewing Gum - Mixed Fruit
# 21312                                              Serum
# 26976                                       Curry Leaves
#
#                      category              sub_category     brand  sale_price  \
# 25301  Kitchen, Garden & Pets    Pet Food & Accessories      Wahl    12500.00
# 21761  Kitchen, Garden & Pets    Pet Food & Accessories   Farmina    10090.00
# ...

# %%
# How much Stock does bb royal and bb Home hold in this dataset.

df[df.brand=='bb Royal']['sale_price'].sum()
# Out:
# 114056.03

# %%
df[df.brand=='BB Home']['sale_price'].sum()
# Out:
# 100160.5

# %%
# How much FRESHO Holds

df[df.brand=='Fresho']['sale_price'].sum()
# Out:
# 54240.81

# %% [markdown]
# - bb Royal has 114056₹ Stocks
# - BB HOME has 100160₹ Stock
# - Fresho has more products that bb royal sbut still it has only 54240₹ of Stock. Due to Cheaper Products.

# %%
df[0:1]
# Out:
#    index                                 product          category  \
# 0      1  Garlic Oil - Vegetarian Capsule 500 mg  Beauty & Hygiene
#
#   sub_category              brand  sale_price  market_price              type  \
# 0    Hair Care  Sri Sri Ayurveda        220.0         220.0  Hair Oil & Serum
#
#    rating                                        description
# 0     4.1  This Product contains Garlic Oil that is known...
